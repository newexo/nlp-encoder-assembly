# %% [markdown]
# # GETTING AND LOADING A CORPUS
#
# https://nlpforhackers.io/corpora/
# http://lucumr.pocoo.org/2015/11/18/pythons-hidden-re-gems/
#
# The goal of this step is to develop an initial list of each character and their spoken lines, or a cleanish list of the lines within the text. (Dictionaries are Hash value arbitrary, so may not be ordered the same. Lists are used instead.)

# %%
# Select and Read a file into "f" using a list and stripping out all Project Gutenberg headers and footers

from pathlib import Path
import re
data_folder = Path("data/poe/")
file_to_open = data_folder / "2149-0.txt"
f = open(file_to_open, 'r')
first_document = list(f)
#print(first_document)

# Determine whether a Project Gutenberg Text
first_header_index = 0
second_header_index = 0
footer_index = 0
if any("GUTENBERG" in s for s in first_document):
    for first_header_index in range( len(first_document) ):
        if ( ( first_document[first_header_index].find('*END*THE SMALL PRINT!') ) != -1 ) :
            break
        else:
            for first_header_index in range( len(first_document) ):
                if ( ( first_document[first_header_index].find('START OF THIS PROJECT GUTENBERG') ) != -1 ) :
                    break        
        
    second_document = list(first_document[first_header_index + 1 :])

    for second_header_index in range( len(second_document) ):
        if ( ( second_document[second_header_index].find('www.gutenberg.org') ) != -1 ) :
            break            
    for footer_index in range( len(first_document) ):
        if ( ( first_document[footer_index].find('End of Project') ) != -1 ) :
            break
        else:
            for footer_index in range( len(first_document) ):
                if ( ( first_document[footer_index].find('End of the Project') ) != -1 ) :
                    break    
        
    print(first_header_index)            
    print(second_header_index)
    print(footer_index)     
    
    script = list()
    if (second_header_index < (first_header_index + 100)):
        script = list(first_document[first_header_index +1 + second_header_index +1 : footer_index-1])
    else:
        script = list(first_document[first_header_index +1 : footer_index-1])
else:
    script = first_document
print(script)
# Out:
# 20
# 9261
# 9276
# ['\n', '\n', '\n', '\n', 'Produced by David Widger\n', '\n', '\n', '\n', '\n', '\n', 'THE WORKS OF EDGAR ALLAN POE\n', '\n', 'IN FIVE VOLUMES\n', '\n', 'VOLUME 3\n', '\n', 'The Raven Edition\n', '\n', '\n', 'CONTENTS:\n', '\n', '     NARRATIVE OF A. GORDON PYM\n', '     LIGEIA\n', '     MORELLA\n', '     A TALE OF THE RAGGED MOUNTAINS\n', '     THE SPECTACLES\n', '     KING PEST\n', '     THREE SUNDAYS IN A WEEK\n', '\n', '\n', '\n', '\n', '\n', 'NARRATIVE OF A. GORDON PYM\n', '\n', 'INTRODUCTORY NOTE\n', '\n', 'UPON my return to the United States a few months ago, after the\n', 'extraordinary series of adventure in the South Seas and elsewhere, of\n', 'which an account is given in the following pages, accident threw me\n', 'into the society of several gentlemen in Richmond, Va., who felt deep\n', 'interest in all matters relating to the regions I had visited, and who\n', 'were constantly urging it upon me, as a duty, to give my narrative to\n', 'the public. I had several reasons, however, for declining to do so, some\n', 'of which were of a nature altogether private, and concern no person but\n', 'myself; others not so much so. One consideration which deterred me was\n', 'that, having kept no journal during a greater portion of the time in\n', 'which I was absent, I feared I should not be able to write, from mere\n', 'memory, a statement so minute and connected as to have the _appearance\n', '_of that truth it would really possess, barring only the natural and\n', 'unavoidable exaggeration to which all of us are prone when detailing\n', 'events which have had powerful influence in exciting the imaginative\n', 'faculties. Another reason was, that the incidents to be narrated were\n', 'of a nature so positively marvellous that, unsupported as my assertions\n', 'must necessarily be (except by the evidence of a single individual, and\n', 'he a half-breed Indian), I could only hope for belief among my family,\n', 'and those of my friends who have had reason, through life, to put faith\n', 'in my veracity--the probability being that the public at large would\n', 'regard what I should put forth as merely an impudent and ingenious\n', 'fiction. A distrust in my own abilities as a writer was, nevertheless,\n', 'one of the principal causes which prevented me from complying with the\n', 'suggestions of my advisers.\n', '\n', 'Among those gentlemen in Virginia who expressed the greatest interest\n', 'in my statement, more particularly in regard to that portion of it\n', 'which related to the Antarctic Ocean, was Mr. Poe, lately editor of\n', 'the “Southern Literary Messenger,” a monthly magazine, published by Mr.\n', 'Thomas W. White, in the city of Richmond. He strongly advised me,\n', 'among others, to prepare at once a full account of what I had seen\n', 'and undergone, and trust to the shrewdness and common-sense of the\n', 'public--insisting, with great plausibility, that however roughly, as\n', 'regards mere authorship, my book should be got up, its very uncouthness,\n', 'if there were any, would give it all the better chance of being received\n', 'as truth.\n', '\n', 'Notwithstanding this representation, I did not make up my mind to do as\n', 'he suggested. He afterward proposed (finding that I would not stir in\n', 'the matter) that I should allow him to draw up, in his own words, a\n', 'narrative of the earlier portion of my adventures, from facts afforded\n', 'by myself, publishing it in the “Southern Messenger” _under the garb\n', 'of fiction. _To this, perceiving no objection, I consented, stipulating\n', 'only that my real name should be retained. Two numbers of the pretended\n', 'fiction appeared, consequently, in the “Messenger” for January and\n', 'February (1837), and, in order that it might certainly be regarded as\n', 'fiction, the name of Mr. Poe was affixed to the articles in the table of\n', 'contents of the magazine.\n', '\n', 'The manner in which this ruse was received has induced me at length to\n', 'undertake a  ...

# %%
#Compile a list of speakers
r = re.compile("[A-Z0-9][A-Z0-9]+")
speakers = []
for line in script:
    mtch = r.match(line)
    if mtch:
        speakers.append(mtch.group())
#print(speakers)

#Omit speakers from the list of text
s = re.compile(r"\b[A-Z{3}\.]+\b")
spoken = list(filter(lambda i: not r.search(i), script))

print(spoken)
# Out:
# ['\n', '\n', '\n', '\n', 'Produced by David Widger\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'The Raven Edition\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'extraordinary series of adventure in the South Seas and elsewhere, of\n', 'which an account is given in the following pages, accident threw me\n', 'into the society of several gentlemen in Richmond, Va., who felt deep\n', 'interest in all matters relating to the regions I had visited, and who\n', 'were constantly urging it upon me, as a duty, to give my narrative to\n', 'the public. I had several reasons, however, for declining to do so, some\n', 'of which were of a nature altogether private, and concern no person but\n', 'myself; others not so much so. One consideration which deterred me was\n', 'that, having kept no journal during a greater portion of the time in\n', 'which I was absent, I feared I should not be able to write, from mere\n', 'memory, a statement so minute and connected as to have the _appearance\n', '_of that truth it would really possess, barring only the natural and\n', 'unavoidable exaggeration to which all of us are prone when detailing\n', 'events which have had powerful influence in exciting the imaginative\n', 'faculties. Another reason was, that the incidents to be narrated were\n', 'of a nature so positively marvellous that, unsupported as my assertions\n', 'must necessarily be (except by the evidence of a single individual, and\n', 'he a half-breed Indian), I could only hope for belief among my family,\n', 'and those of my friends who have had reason, through life, to put faith\n', 'in my veracity--the probability being that the public at large would\n', 'regard what I should put forth as merely an impudent and ingenious\n', 'fiction. A distrust in my own abilities as a writer was, nevertheless,\n', 'one of the principal causes which prevented me from complying with the\n', 'suggestions of my advisers.\n', '\n', 'Among those gentlemen in Virginia who expressed the greatest interest\n', 'in my statement, more particularly in regard to that portion of it\n', 'which related to the Antarctic Ocean, was Mr. Poe, lately editor of\n', 'the “Southern Literary Messenger,” a monthly magazine, published by Mr.\n', 'Thomas W. White, in the city of Richmond. He strongly advised me,\n', 'among others, to prepare at once a full account of what I had seen\n', 'and undergone, and trust to the shrewdness and common-sense of the\n', 'public--insisting, with great plausibility, that however roughly, as\n', 'regards mere authorship, my book should be got up, its very uncouthness,\n', 'if there were any, would give it all the better chance of being received\n', 'as truth.\n', '\n', 'Notwithstanding this representation, I did not make up my mind to do as\n', 'he suggested. He afterward proposed (finding that I would not stir in\n', 'the matter) that I should allow him to draw up, in his own words, a\n', 'narrative of the earlier portion of my adventures, from facts afforded\n', 'by myself, publishing it in the “Southern Messenger” _under the garb\n', 'of fiction. _To this, perceiving no objection, I consented, stipulating\n', 'only that my real name should be retained. Two numbers of the pretended\n', 'fiction appeared, consequently, in the “Messenger” for January and\n', 'fiction, the name of Mr. Poe was affixed to the articles in the table of\n', 'contents of the magazine.\n', '\n', 'The manner in which this ruse was received has induced me at length to\n', 'undertake a regular compilation and publication of the adventures in\n', 'question; for I found that, in spite of the air of fable which had been\n', 'so ingeniously thrown around that portion of my statement which appeared\n', 'in the “Messenger” (without altering or distorting a single fact),\n', 'the public were still not at all disposed to receive it as fable, and\n', 'several letters were sent to Mr. P.’s address, distinctly expressing\n', 'a conviction to the contrary. I thenc ...

# %% [markdown]
# # RE-CREATING SENTENCES AND PHRASES
#
# During this step, we concatenate lines in batches to allow the identification of sentences with regular expressions. Then we identify phrases with stop words.

# %%
#Concatenate lines into list entries for future sentence splitting

newLines = []
singleLine = ''
singleLines = []

#Remove all line returns(ok)
for j in range(0, len(spoken)):
    spoken[j] = spoken[j].replace('\n', '')
    
#Split 5 lines at a time into new list
for k in range( 0, len(spoken), 3):
    newLines = []
    for line in range( 0, 3 ):
        try:
            newLines.append(' '+spoken[line+k])
        except:
            #print("Index Error at", k, line)
            break
    #Join 5-line groups into one line and append to a list
    singleLine = ''.join(newLines)
    singleLines.append(singleLine)

#print(singleLines)

# %%
#Create list of sentences
sentences = []
for m in range(0, len(singleLines)):
    mtch = re.findall("[A-Z][^\.!?]*[\.!?]", singleLines[m], re.M|re.I)
    if mtch:
        sentences.append(mtch)

print(sentences)
# Out:
# [['extraordinary series of adventure in the South Seas and elsewhere, of which an account is given in the following pages, accident threw me into the society of several gentlemen in Richmond, Va.'], ['were constantly urging it upon me, as a duty, to give my narrative to of which were of a nature altogether private, and concern no person but myself; others not so much so.'], ['unavoidable exaggeration to which all of us are prone when detailing events which have had powerful influence in exciting the imaginative faculties.'], ['in my veracity--the probability being that the public at large would one of the principal causes which prevented me from complying with the suggestions of my advisers.'], ['which related to the Antarctic Ocean, was Mr.', 'Poe, lately editor of the “Southern Literary Messenger,” a monthly magazine, published by Mr.'], ['as truth.'], ['by myself, publishing it in the “Southern Messenger” _under the garb only that my real name should be retained.'], ['February (1837), and, in order that it might certainly be regarded as fiction, the name of Mr.', 'Poe was affixed to the articles in the table of contents of the magazine.'], ['narrative would prove of such a nature as to carry with them sufficient to fear on the score of popular incredulity.'], ['This_ exposé _being made, it will be seen at once how much of what that no fact is misrepresented in the first few pages which were written by Mr.', 'Poe.'], ['it will be unnecessary to point out where his portion ends and my own commences; the difference in point of style will be readily perceived.'], ['an attorney in good practice.'], ['speculated very successfully in stocks of the Edgarton New Bank, as it was formerly called.', 'By these and other means he had managed to lay by a of his property at his death.'], ['the school of old Mr.', 'Ricketts, a gentleman with only one arm and of eccentric manners--he is well known to almost every person who has with the son of Mr.'], ['employ of Lloyd and Vredenburgh--Mr.', 'Barnard is also very well known in was named Augustus, and he was nearly two years older than myself.'], ['was always talking to me of his adventures in the South Pacific Ocean.', 'all night.'], ['Island of Tinian, and other places he had visited in his travels.', 'At Ariel, and worth about seventy-five dollars.', 'She had a half-deck or hold ten persons without much crowding.'], ['to-day.', 'longer and more momentous narrative.', 'One night there was a party at Mr.'], ['Barnard’s, and both Augustus and myself were not a little intoxicated quietly (it being near one when the party broke up), and without saying a word on his favorite topic.'], ['liquors he had drunk had set him entirely beside himself.', 'He proceeded intoxicated, but that he was never more sober in his life.'], ['was determined to get up and dress, and go out on a frolic with the pleasure, and thought his mad idea one of the most delightful and most reasonable things in the world.'], ['as himself, and quite as tired as he was of lying in bed like a dog, and quite as ready for any fun or frolic as any Augustus Barnard in Nantucket.'], ['We lost no time in getting on our clothes and hurrying down to the boat.'], ['Co.', 'and almost thumping her side out against the rough logs.', 'Augustus got into her and bailed her, for she was nearly half full of water.'], ['out to sea.', 'myself by the mast, on the deck of the cuddy.'], ['rate--neither of us having said a word since casting loose from the what time he thought it probable we should get back.'], ['that, in spite of his assumed _nonchalance_, he was greatly agitated.'], ['nautical skill of my friend.', 'The wind, too, had suddenly increased, as to betray any trepidation, and for almost half an hour maintained a Augustus about the propriety of turning back.'], ['a minute before he made answer, or took any notice of my suggestion.', 'expected a similar reply, but there was something in the tone of these looked at the speaker attentively.'],  ...

# %%
#Clean the stopword list
stoplist = []
clean_line = []
data_folder = Path("data/")
file_to_open = data_folder / "snowball_stop.txt"
f = open(file_to_open, 'r')
full_stop = list(f)

for n in range( 0, len(full_stop), 1 ):
    clean_line = full_stop[n].split('|')
    stoplist.append(clean_line[0])

for p in range(len(stoplist)):
    stoplist[p] = stoplist[p].replace('\n', '')
    
#print(stoplist)

# %%
# Create list of phrases using stopwords
phrases = []
candidate_phrases = []

for q in range(len(sentences)):
    for r in sentences[q]:
        words = re.split("\\s+", r)
        previous_stop = False
 
        # Examine each word to determine if it is a phrase boundary marker or part of a phrase or alone
        for w in words:
 
            if w in stoplist and not previous_stop:
                # phrase boundary encountered, so put a hard indicator
                candidate_phrases.append(";")
                previous_stop = True
            elif w not in stoplist and len(w) > 3:
                # keep adding words to list until a phrase boundary is detected
                candidate_phrases.append(w.strip())
                previous_stop = False
 
    # Create a list of candidate phrases without boundary demarcation
    phrases = re.split(";+", ' '.join(candidate_phrases))

# Clean up phrases    
re2 = re.compile('[^\.!?,"(){}\*:]*[\.!?,"(){}\*:]')
for s in range(len(phrases)):
    phrases[s] = re.sub(re2, '', phrases[s])
    phrases[s] = phrases[s].strip(' ')
    phrases[s] = phrases[s].replace(' ', '_')
    phrases[s] = phrases[s].replace('__', '_')
    phrases[s] = phrases[s].strip('_')

for s in range(len(phrases)):
    try:
        phrases.remove('')
        phrases.remove(' ')
        phrases.remove('/n')
    except:
        pass
    
#for t in range(50):
    #print(phrases[t])

#print(phrases)
# Out:
# ['extraordinary_series', 'adventure', 'South_Seas', 'account_given', 'accident_threw', 'society', 'several_gentlemen', 'were_constantly_urging_upon', 'give_narrative', 'were', 'concern', 'person', 'myself', 'others', 'much_unavoidable_exaggeration', 'prone', 'detailing_events', 'have_powerful_influence', 'exciting', 'veracity--the_probability_being', 'public', 'large', 'principal_causes', 'prevented', 'complying', 'suggestions', 'related', 'lately_editor', '”', 'published', 'publishing', '“Southern_Messenger”_under', 'garb', 'real_name', 'order', 'might_certainly_regarded', 'name', 'affixed', 'articles', 'table', 'contents', 'narrative', 'prove', 'nature', 'carry', 'them_sufficient', 'fear', 'score', 'will_seen', 'much', 'fact_misrepresented', 'first', 'pages', 'were_written', 'will_unnecessary', 'point', 'portion_ends', 'commences', 'difference', 'point', 'attorney', 'speculated', 'successfully', 'stocks', 'means_managed', 'property', 'school', 'gentleman', 'eccentric_manners--he_well_known', 'almost_every_person', 'employ', 'Lloyd', 'Barnard_also', 'well_known', 'nearly_years_older', 'always_talking', 'adventures', 'Island', 'places_visited', 'worth', 'half-deck', 'longer', 'night', 'party', 'Augustus', 'myself_were', 'little_intoxicated_quietly_being_near', 'without_saying', 'word', 'never', 'sober', 'determined', 'frolic', 'thought_idea', 'delightful', 'reasonable_things', 'quite', 'tired', 'lying', 'like', 'quite', 'ready', 'frolic', 'Augustus_Barnard', 'lost', 'time', 'getting', 'clothes', 'hurrying', 'almost_thumping_side', 'Augustus', 'nearly_half_full', 'myself', 'deck', 'rate--neither', 'having_said', 'word_since_casting_loose', 'time_thought_probable', 'spite', 'nautical_skill', 'betray', 'almost_half', 'hour_maintained', 'Augustus', 'propriety', 'minute', 'took', 'notice', 'expected', 'something', 'tone', 'looked', 'knees_shook', 'violently_together', 'seemed_scarcely_able', 'are_going', 'tiller', 'falling_forward', 'bottom', 'nothing_the--matter--going_home--d--d--don’t', 'imitate', 'outward_demeanour', 'perfect_possession', 'confused_perception', 'doubt', 'perilous_situation_assisted', 'hastening', 'hardly_possible', 'conceive', 'extremity', 'sight', 'land', 'beyond', 'possibility', 'making', 'boat_going', 'water', 'terrible_rate--full', 'wind--no_reef', 'either', 'mainsail--running_bows_completely', 'thousand_wonders', 'nearly_unconscious', 'rushing', 'mainsail', 'carried_away', 'mast_short', 'This_latter_accident_alone_along', 'shipping_heavy_seas_occasionally', 'remained', 'chance', 'made', 'mind', 'bear_whatever_might_happen', 'fortitude', 'scream', 'throats', 'seemed', 'veins--my_heart_ceased_utterly', 'without_having', 'insensible_upon', 'body', 'bound', 'Several_persons_were_standing', 'paler', 'busily_occupied', 'exclamations', 'gratitude', 'excited_alternate_laughter', 'tears', 'rough-looking_personages', 'Several_were', 'perceive_boat', 'impossibility', 'avoid_coming', 'contact--their_shouts', 'warning_upon_seeing_were', 'terribly_alarmed', 'little_vessel', 'have_passed', 'without', 'least_perceptible_impediment', 'mingling', 'roar', 'wind', 'frail_bark', 'swallowed', 'rubbed', 'moment_along', 'keel', 'destroyer--but', 'mere_shell_adrift', 'Captain_troubling_himself', 'nobody’s_fault', 'might_drown', 'dammed”', 'language', 'speech_evincing', 'base', 'degree', 'orders', 'were_hanged', 'moment_foot', 'flew', 'saved--allowing', 'have_been', 'board', 'pieces', 'good_fortune', 'attributed', 'wise', 'pious', 'special_interference', 'While', 'ship', 'mate_lowered', 'jolly-boat', 'seen', 'starting', 'seat_bawled', 'crew', 'time', 'gotten_fully', 'although', 'hands', 'board_were_making_great_exertions', 'take', 'main-chains', 'soon', 'made', 'lurches_disengaged', 'perilous_situation', 'taken', 'board--for', 'body_proved', 'started', 'broken', 'passage', 'arrested', 'manner', 'There', 'surgeon', 'atrocious_behaviour', 'previous_portion', 'Henderson', 'although', 'wind_blowing_almost', 'minutes', 'fell', 'fragment ...

# %% [markdown]
# # PERFORM A PHRASE FREQUENCY COUNT
#
# Now we can identify common phrases by performing a frequency count on each phrase.  Moreover, if the corpus is large enough, commonly used phrases will be evident with higher counts across many texts.  For this reason the phrase list along with counts, will be stored in a file.

# %%
# Phrase frequency count
from operator import itemgetter
wordfreq = []
for u in range(len(phrases)):
    utterance = phrases[u]
    uttcnt = 0
    uttcnt = phrases.count(utterance)
    if uttcnt > 1:
        wordfreq.append(uttcnt)
    
zipped = list(zip(phrases, wordfreq))
sortzip = sorted(zipped, key=itemgetter(1), reverse=True)

for v in range(50):
    print(sortzip[v])

# %% [markdown]
# # TERM FREQUENCY–INVERSE DOCUMENT FREQUENCY (TF-IDF)
# ![image.png](attachment:image.png)
# The quintessential early Natural Language Processing tool, the TF-IDF analysis for context and sentiment evaluation is useful only over a large corpus. It must be understood that the corpus is not just a sample to be evaluated, but instead is the entire population that sets a 'benchmark' for evaluation, if you will.
#
# Here we establish a Term Frequency (TF) count of word frequencies, just as we showed a phrase frequency count in the last step in this notebook.

# %%
#Establish wordList
wordList = []
for u in range(len(sentences)):
    for v in sentences[u]:
        words = re.split("\\s+", v)
        wordList.extend(words)
        
for w in range(50):
    print(wordList[w])

# %%
#Establish wordDict
wordDict = {}
for w in range(len(wordList)):
    newWord = wordList[w]
    newWord = newWord.lower()
    newWord = newWord.replace('.', '')
    wordDict[w] = newWord
#print(wordDict)
    
#Perform word counts on dict
countDict = {}
for x in range(len(wordDict)):
    term = wordDict[x]
    count = 1
    for y in range(len(wordDict)):
        try:
            if wordDict[y].find(term) > 0:
                count += 1
        except:
            pass
        countDict[term] = count

#for k, v in countDict.items():
    #print(k, v)

# %%
# Computes ratio of word's appearances to total words
bow = wordList
bowCount = len(bow) #BOW = Bag of Words
tfDict = {}
for term, count in countDict.items():
    tfDict[term] = count/float(bowCount)

num = dict(sorted(tfDict.items(), key=lambda x: x[1], reverse = True))
for k, v in num.items():
    print(k, v)

# %% [markdown]
# ## TO BE CONTINUED...
# At this point, this notebook is finished. Please refer to Part 2 for a continuation of this process, wherein the code in this notebook is converted into objects and a multiple document corpus is compiled.
