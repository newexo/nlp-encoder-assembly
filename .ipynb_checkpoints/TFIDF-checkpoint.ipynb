# %% [markdown]
# # GETTING AND LOADING A CORPUS
#
# https://nlpforhackers.io/corpora/
# http://lucumr.pocoo.org/2015/11/18/pythons-hidden-re-gems/
#
# The goal of this step is to develop an initial list of each character and their spoken lines. Dictionaries are Hash value arbitrary, so may not be ordered the same.

# %%
#Select and Read a file into "f" using a list and stripping out all Project Gutenberg headers and footers
from pathlib import Path
import re
idx = 1
data_folder = Path("data/shakespeare/")
file_to_open = data_folder / "1513-0.txt"
f = open(file_to_open, 'r')
first_document = list(f)
#print(first_document)

first_header_index = 0
second_header_index = 0
footer_index = 0

for first_header_index in range( len(first_document) ):
    if ( ( first_document[first_header_index].find('*END*THE SMALL PRINT!') ) != -1 ) :
        break
    else:
        for first_header_index in range( len(first_document) ):
            if ( ( first_document[first_header_index].find('START OF THIS PROJECT GUTENBERG') ) != -1 ) :
                break        
        
second_document = list(first_document[first_header_index + 1 :])

for second_header_index in range( len(second_document) ):
    if ( ( second_document[second_header_index].find('www.gutenberg.org') ) != -1 ) :
        break            
for footer_index in range( len(first_document) ):
    if ( ( first_document[footer_index].find('End of Project') ) != -1 ) :
        break
    else:
        for footer_index in range( len(first_document) ):
            if ( ( first_document[footer_index].find('End of the Project') ) != -1 ) :
                break    
        
print(first_header_index)            
print(second_header_index)
print(footer_index)     
    
script = list()
if (second_header_index < (first_header_index + 100)):
    script = list(first_document[first_header_index +1 + second_header_index +1 : footer_index-1])
else:
    script = list(first_document[first_header_index +1 : footer_index-1])
#print(script)
# Out:
# 24
# 5276
# 5294

# %%
#Compile a list of speakers
r = re.compile("[A-Z0-9][A-Z0-9]+")
speakers = []
for line in script:
    mtch = r.match(line)
    if mtch:
        speakers.append(mtch.group())
#print(speakers)

#Omit speakers from the list of text
s = re.compile(r"\b[A-Z{3}\.]+\b")
spoken = list(filter(lambda i: not s.search(i), script))

print(spoken)
# Out:
# ['\n', '\n', '\n', 'a team of about twenty Project Gutenberg volunteers.\n', '\n', '\n', '\n', '\n', '\n', 'by William Shakespeare\n', '\n', '\n', '\n', '\n', '\n', '\n', 'Contents\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', ' Dramatis Personæ\n', '\n', 'Page to Paris.\n', '\n', '\n', 'Servants.\n', '\n', 'An Apothecary.\n', 'Three Musicians.\n', 'An Officer.\n', 'Citizens of Verona; several Men and Women, relations to both houses;\n', 'Maskers, Guards, Watchmen and Attendants.\n', '\n', 'Fifth Act, at Mantua.\n', '\n', '\n', '\n', ' Enter Chorus.\n', '\n', 'Two households, both alike in dignity,\n', 'In fair Verona, where we lay our scene,\n', 'From ancient grudge break to new mutiny,\n', 'Where civil blood makes civil hands unclean.\n', 'From forth the fatal loins of these two foes\n', 'Whose misadventur’d piteous overthrows\n', 'Doth with their death bury their parents’ strife.\n', 'The fearful passage of their death-mark’d love,\n', 'And the continuance of their parents’ rage,\n', 'Which, but their children’s end, nought could remove,\n', 'Is now the two hours’ traffic of our stage;\n', 'The which, if you with patient ears attend,\n', 'What here shall miss, our toil shall strive to mend.\n', '\n', '\n', '\n', '\n', '\n', '\n', ' Enter Sampson and Gregory armed with swords and bucklers.\n', '\n', 'Gregory, on my word, we’ll not carry coals.\n', '\n', 'No, for then we should be colliers.\n', '\n', '\n', 'Ay, while you live, draw your neck out o’ the collar.\n', '\n', '\n', 'But thou art not quickly moved to strike.\n', '\n', '\n', 'To move is to stir; and to be valiant is to stand: therefore, if thou\n', 'art moved, thou runn’st away.\n', '\n', '\n', 'That shows thee a weak slave, for the weakest goes to the wall.\n', '\n', 'True, and therefore women, being the weaker vessels, are ever thrust to\n', 'thrust his maids to the wall.\n', '\n', 'The quarrel is between our masters and us their men.\n', '\n', '\n', 'The heads of the maids?\n', '\n', 'Ay, the heads of the maids, or their maidenheads; take it in what sense\n', 'thou wilt.\n', '\n', 'They must take it in sense that feel it.\n', '\n', 'pretty piece of flesh.\n', '\n', '’Tis well thou art not fish; if thou hadst, thou hadst been poor John.\n', 'Draw thy tool; here comes of the house of Montagues.\n', '\n', ' Enter Abram and Balthasar.\n', '\n', '\n', 'How? Turn thy back and run?\n', '\n', 'Fear me not.\n', '\n', '\n', 'Let us take the law of our sides; let them begin.\n', '\n', '\n', 'them if they bear it.\n', '\n', 'Do you bite your thumb at us, sir?\n', '\n', '\n', 'Do you bite your thumb at us, sir?\n', '\n', '\n', 'No.\n', '\n', '\n', 'Do you quarrel, sir?\n', '\n', 'Quarrel, sir? No, sir.\n', '\n', '\n', 'No better.\n', '\n', 'Well, sir.\n', '\n', ' Enter Benvolio.\n', '\n', 'Say better; here comes one of my master’s kinsmen.\n', '\n', 'Yes, better, sir.\n', '\n', 'You lie.\n', '\n', 'Draw, if you be men. Gregory, remember thy washing blow.\n', '\n', '\n', 'Part, fools! put up your swords, you know not what you do.\n', '\n', '\n', ' Enter Tybalt.\n', '\n', 'What, art thou drawn among these heartless hinds?\n', 'Turn thee Benvolio, look upon thy death.\n', '\n', 'Or manage it to part these men with me.\n', '\n', 'Have at thee, coward.\n', '\n', '\n', ' Enter three or four Citizens with clubs.\n', '\n', 'Clubs, bills and partisans! Strike! Beat them down!\n', 'Down with the Capulets! Down with the Montagues!\n', '\n', ' Enter Capulet in his gown, and Lady Capulet.\n', '\n', 'What noise is this? Give me my long sword, ho!\n', '\n', '\n', 'And flourishes his blade in spite of me.\n', '\n', ' Enter Montague and his Lady Montague.\n', '\n', 'Thou villain Capulet! Hold me not, let me go.\n', '\n', 'Thou shalt not stir one foot to seek a foe.\n', '\n', ' Enter Prince Escalus, with Attendants.\n', '\n', 'Rebellious subjects, enemies to peace,\n', 'Profaners of this neighbour-stained steel,—\n', 'Will they not hear? What, ho! You m ...

# %%
#Concatenate lines into list entries for future sentence splitting

newLines = []
singleLine = ''
singleLines = []

#Remove all line returns(ok)
for j in range(0, len(spoken)):
    spoken[j] = spoken[j].replace('\n', '')
    
#Split 5 lines at a time into new list
for k in range( 0, len(spoken), 3):
    newLines = []
    for line in range( 0, 3 ):
        try:
            newLines.append(' '+spoken[line+k])
        except:
            print("Index Error at", k, line)
            break
    #Join 5-line groups into one line and append to a list
    singleLine = ''.join(newLines)
    singleLines.append(singleLine)

#print(singleLines)

# %%
#Create list of sentences
sentences = []
for m in range(0, len(singleLines)):
    mtch = re.findall("[A-Z][^\.!?]*[\.!?]", singleLines[m], re.M|re.I)
    if mtch:
        sentences.append(mtch)
#print(sentences)

# %%
#Clean the stopword list
stoplist = []
clean_line = []
data_folder = Path("data/")
file_to_open = data_folder / "snowball_stop.txt"
f = open(file_to_open, 'r')
full_stop = list(f)

for n in range( 0, len(full_stop), 1 ):
    clean_line = full_stop[n].split('|')
    stoplist.append(clean_line[0])

for p in range(len(stoplist)):
    stoplist[p] = stoplist[p].replace('\n', '')
    
#print(stoplist)

# %%
#Create list of phrases using stopwords
phrases = []
candidate_phrases = []

for q in range(len(sentences)):
    for r in sentences[q]:
        words = re.split("\\s+", r)
        previous_stop = False
 
        # examine each word to determine if it is a phrase boundary marker or part of a phrase or alone
        for w in words:
 
            if w in stoplist and not previous_stop:
                # phrase boundary encountered, so put a hard indicator
                candidate_phrases.append(";")
                previous_stop = True
            elif w not in stoplist and len(w) > 3:
                # keep adding words to list until a phrase boundary is detected
                candidate_phrases.append(w.strip())
                previous_stop = False
 
    # get a list of candidate phrases without boundary demarcation
    phrases = re.split(";+", ' '.join(candidate_phrases))

# Clean up phrases    
re2 = re.compile('[^\.!?,"(){}\*:]*[\.!?,"(){}\*:]')
for s in range(len(phrases)):
    phrases[s] = re.sub(re2, '', phrases[s])
    phrases[s] = phrases[s].strip(' ')
    phrases[s] = phrases[s].replace(' ', '_')
    phrases[s] = phrases[s].replace('__', '_')
    phrases[s] = phrases[s].strip('_')

for s in range(len(phrases)):
    try:
        phrases.remove('')
        phrases.remove(' ')
        phrases.remove('/n')
    except:
        pass
    
for t in range(len(phrases)):
    print(phrases[t])
# Out:
# team
# Page
# Watchmen
# From_ancient_grudge_break
# From_forth
# fatal_loins
# foes_Whose_misadventur’d_piteous_overthrows_Doth
# hours’_traffic
# stage
# What
# toil_shall_strive
# Enter_Sampson
# Gregory_armed
# swords
# we’ll
# draw_your_neck
# thou
# quickly_moved
# move
# stir
# valiant
# That_shows_thee
# weakest_goes
# being
# ever_thrust
# thrust_maids
# quarrel
# masters
# heads
# heads
# their_maidenheads
# take
# They_must_take
# sense
# feel_pretty_piece
# well_thou
# fish
# Draw_tool
# comes
# house
# Enter_Abram
# Turn_back
# take
# sides
# them
# they_bear_bite_your_thumb
# bite_your_thumb
# better
# comes
# know
# thou_drawn_among
# manage
# part
# Have
# Enter_three
# four_Citizens
# bills
# Down
# Down
# Enter_Capulet
# flourishes_blade
# spite
# Enter_Montague
# Thou_shalt
# stir_foot
# seek
# Will_they
# pain
# bloody_hands_Throw_your_mistemper’d_weapons
# ground_hear
# sentence
# Canker’d
# Your_lives_shall
# forfeit
# know_farther_pleasure
# pain
# were
# swung
# hiss’d
# Came
# fought
# part
# Till
# Where_underneath
# grove
# sycamore_That_westward_rooteth
# stole
# covert
# gladly_shunn’d
# gladly_fled
# private
# Shuts
# locks_fair_daylight
# makes_himself
# Black
# portentous_must
# Unless_good_counsel
# know
# Have_importun’d
# envious_worm_spread_sweet_leaves
# dedicate_beauty
# Could
# learn
# willingly_give_cure
# father
# went_hence
# having
# Alas
# love
# gentle
# Should
# tyrannous
# rough
# Alas
# pathways
# Misshapen_chaos
# Feather
# Dost_thou
# Which_thou_wilt_propagate
# have_prest_With
# This_love
# thou_hast_shown_Doth
# grief
# much
# This
# he’s
# Tell
# sadness
# hath_Dian’s_wit
# strong_proof
# That
# Then_hath_sworn
# Cuts_beauty
# wise
# wisely
# merit_bliss
# hath_forsworn
# rul’d
# forget
# think
# Examine
# strucken_blind
# forget_precious_treasure
# What_doth_beauty_serve
# thou_canst
# teach
# Paris
# keep
# pity_’tis_liv’d
# odds
# hath
# seen
# change
# fourteen_years
# summers_wither
# their_pride_think_ripe
# Younger
# soon_marr’d
# Lies_consent
# even
# delight_Among_fresh_female_buds_shall
# night_Inherit
# like
# whose_merit
# view
# stand
# though
# house
# welcome
# Find_them
# Enter_Benvolio
# rank_poison
# Your_plantain_leaf_excellent
# bound
# madman_Shut
# Whipp’d
# mine
# fortune
# Signior_Valentio
# cousin_Tybalt
# Lucio
# Whither
# With
# admired_beauties
# burnt
# fairer
# all-seeing_Ne’er_match_since_first
# crystal_scales
# weigh’d_Your_lady’s_love
# maid_shall_scant_show_well
# rejoice
# splendour
# Enter_Lady_Capulet
# Call_forth
# Where’s
# This
# must_talk
# Thou_knowest_daughter’s
# She’s
# Even
# days
# Come_Lammas
# Susan
# —God_rest
# Were
# When_taste
# wormwood
# nipple
# fall
# have
# waddled
# about
# even
# —God
# Thou_wilt_fall_backward
# thou_hast
# wit
# Thou_wilt_fall_backward
# thou_comest
# age
# marry
# theme_stands_your_disposition
# Here
# ladies
# count_That
# valiant_Paris_seeks
# world—why_he’s
# Verona’s_summer_hath
# he’s
# faith
# love
# This_night_shall_behold
# feast
# Read_o’er
# volume
# find_delight_writ
# Find_written
# margent
# fish_lives
# sea
# ’tis_much_pride_fair_without
# fair_within
# That
# gold_clasps_locks
# golden_story
# shall_share
# making_yourself
# Women_grow
# like
# Than_your_consent_gives_strength
# Enter
# Nurse_cursed
# everything
# seek_happy_nights
# five
# Maskers
# Torch-bearers
# shall
# speech_spoke
# shall
# them_measure
# We’ll_measure_them
# soar
# them
# sink
# burden_love
# great_oppression
# love
# boisterous
# love_rough
# rough
# love
# Prick_love
# Here
# beetle-brows_shall_blush
# every_betake
# wherein_thou_stickest
# that’s
# waste_lights
# light_lights
# judgment_sits_Five_times
# mean_well
# going
# mask
# ’tis
# Well
# Made
# joiner_squirrel
# Time
# mind
# Drums
# starts
# wakes
# swears
# prayer
# Thou_talk’st
# Even
# frozen_bosom
# puffs_away
# Turning_side
# This_wind_talk
# blows
# shall_come
# With
# night’s_revels
# expire
# term
# clos’d
# breast
# vile_forfeit
# hath
# steerage
# helps
# shift
# scrape
# When_good_manners_shall
# ’tis
# Away
# remove
# look
# save
# piece
# marchpane
# thou_loves
# porter
# Susan_Grindstone
# Antony
# looked
# asked
# Guests
# Gentlewomen
# ladies
# have_their_toes_Unplagu’d
# corns_will_have
# bout
# Will_deny
# Such
# please
# quench
# room_grown
# Were
# Come_Pentecost
# quickly
# Some_five
# twenty_years
# sir
# doth_enrich
# Beauty
# rich
# earth
# shows
# snowy_dove_trooping
# This
# fleer
# scorn
# foe
# scorn
# solemnity
# virtuous
# Here
# will
# Show
# fair_presence
# ill-beseeming_semblance
# You’ll
# You’ll_make
# you’ll
# ’tis
# princox
# Patience_perforce
# wilful_choler_meeting_Makes_flesh_tremble
# convert
# ready_stand_smooth
# rough_touch
# saints_have_hands
# palm
# Have
# lips
# they_must
# lest_faith_turn
# Saints
# though_grant
# Thus
# Then_have_lips
# kiss
# your_mother_craves
# word
# mother
# lady
# wise
# Shall_have
# gone
# sport
# prepare
# have
# Come
# let’s
# heir
# What’s
# going
# What’s
# grave_like
# love_sprung
# known
# Prodigious_birth
# love
# strangers
# That_fair
# love_groan’d
# Tempering_extremities
# Enter_Benvolio
# life_hath_stol’n_home
# leap’d
# Appear_thou
# likeness
# When_King_Cophetua_lov’d
# demesnes
# That
# likeness_thou_appear
# This
# Till_laid
# conjur’d_down
# That_were
# hath_himself_among
# trees_consorted
# best_befits
# love
# will
# wish_mistress_were
# kind
# fruit_maids_call_medlars
# open-arse
# thou
# This_field-bed
# cold
# shall_then
# ’tis
# vain_seek
# means
# jests
# scars
# never_felt
# Juliet_appears
# light
# Juliet
# already_sick
# pale
# That_thou_maid
# fair
# vestal_livery
# sick
# none
# What
# fairest_stars
# Having
# entreat_eyes_twinkle
# What
# they
# Would
# airy_region_stream
# bright_That_birds
# sing
# think_were
# sails_upon
# bosom
# Deny_father
# name
# enemy
# though
# part_What’s
# were
# Retain
# dear_perfection
# owes_Without
# part
# Take
# thus_bescreen’d
# night_stumblest
# Because
# enemy
# thou
# tell
# considering
# stony_limits
# love
# Therefore_kinsmen
# stop
# lies
# peril
# thine_Than_twenty
# wanting
# whose_direction_found’st_thou
# Than
# have
# cunning
# true-love_passion
# therefore_pardon
# impute
# yielding
# Which
# dark_night_hath
# That_monthly_changes
# Lest
# swear
# This
# prove
# beauteous_flower
# sweet_repose
# rest_Come
# heart
# Th’exchange
# love’s_faithful
# Would’st_thou_withdraw
# frank
# bounty
# boundless
# Being
# flattering_sweet
# Where
# time_thou_wilt_perform
# follow_thee_lord_throughout
# cease_strife
# leave
# Love_goes_toward_love
# schoolboys
# love
# towards_school
# lure
# With_repetition
# soul
# silver-sweet_sound_lovers’_tongues
# Like_softest_music
# hour
# stand
# till_thou_remember_Forgetting
# home
# loving-jealous
# peace
# darkness_fleckled_like
# made
# Titan’s_wheels_help
# crave
# dear
# Enter_Friar_Lawrence
# night’s_dank
# With_baleful_weeds
# womb_children
# divers_kind_sucking
# Many
# None
# Revolts
# stumbling
# vice_sometime’s
# slays
# senses
# Full_soon
# canker_death_eats
# What_early_tongue
# argues
# distemper’d_head_soon
# good_morrow
# Romeo_hath
# been
# That_last_true
# Wast_thou
# Where
# sudden_hath_wounded_That’s
# Within_help
# homely
# drift
# Riddling_confession_finds
# Then_plainly_know_heart’s_dear_love
# fair_daughter
# save
# That_thou_consent
# What
# thou_didst_love
# Young_men’s_love
# lies_truly
# deal
# brine_Hath_wash’d_sallow_cheeks
# doth
# sighs
# groans_ring
# upon_cheek
# stain_doth
# tear
# wash’d
# Thou
# woes_were
# Pronounce
# there’s
# strength
# Thou_chidd’st
# grave_another
# Doth_grace
# grace
# love
# love_read
# alliance
# turn_your_households’_rancour
# Wisely
# slow
# they_stumble
# Enter_Benvolio
# Where
# devil
# Romeo_Came
# torments
# kinsman
# hath_sent
# letter
# Romeo_will_answer
# write_answer
# will_answer
# eye
# heart_cleft
# fights
# gentleman
# first
# stand
# much
# form
# they
# numbers
# Petrarch_flowed
# harlots
# Thisbe
# grey
# There’s
# French_salutation
# gave
# slip
# case
# mine
# That’s
# much
# case
# yours_constrains
# Thou_hast
# kindly_Pink
# Come
# good_Benvolio
# Thou_wast_never
# thou_wast
# well_served
# thee
# wide
# better
# groaning
# thou_Romeo
# thou
# well
# runs_lolling
# hide_bauble
# Thou_desirest
# stop
# tale
# Enter_Nurse
# two
# shirt
# hide_face
# fan’s
# prick
# What
# hath_made
# himself
# well_said
# himself
# quoth_fault
# i’faith
# will_endite
# sir
# unless
# something_stale
# much
# will_come
# We’ll
# ancient_lady
# minute
# will_stand
# thou_must_stand
# suffer_every_knave
# deal_double
# truly_were
# thing
# offered
# Thou_dost
# shriv’d
# Here
# sir
# behind
# bring_thee_cords_made_like
# Which
# high_topgallant
# Must_convoy
# Farewell
# commend
# mistress
# looks
# pale
# clout
# Doth
# rosemary
# Romeo_begin
# hath
# prettiest_sententious
# good
# hear_Commend
# Before
# half
# hour_promised
# Perchance
# That’s
# therefore_hath
# She’d
# swift
# motion
# ball
# words
# bandy
# many_feign
# they_were_dead
# heavy
# pale
# Enter_Nurse
# Hast_thou
# stay
# playing
# sour
# thou
# thou_hast_breath
# thou
# longer
# news_good
# Answer
# that
# is’t_good
# have_made
# simple_choice
# know
# choose
# excels
# hand
# though_they
# have_dined
# What_says
# What
# beats
# fall
# Beshrew_your_heart
# sending
# catch_death
# jauncing
# tell
# Where
# poultice
# Here’s
# Have_leave
# Then_hence
# Friar_Lawrence’_cell
# There_stays
# husband
# make
# comes
# wanton_blood
# They’ll
# scarlet_straight
# Must_climb
# bird’s_nest_soon
# shall_bear
# burden_soon
# Enter_Friar_Lawrence
# smile
# heavens_upon
# holy_That_after-hours
# come
# countervail
# exchange
# That_short_minute_gives
# their_triumph_die
# like_fire
# Which
# loathsome
# taste_confounds
# swift_arrives
# tardy
# Will_ne’er_wear
# fall
# Good_even
# much
# else_thanks
# Unfold
# imagin’d_happiness
# Receive
# either
# Conceit
# rich
# matter
# Brags
# shall
# stay_alone_Till_holy_church_incorporate
# Page
# claps_sword_upon
# says_‘God_send
# need
# operation
# second_draws
# indeed
# soon_moved
# soon_moody
# kill
# hair
# hair_less
# beard
# Thou_wilt_quarrel
# having
# reason
# What
# head
# full
# quarrels
# full
# head_hath_been_beaten
# addle
# wakened
# hath_lain_asleep
# Didst_thou
# fall
# tailor
# wearing_doublet
# another
# tying_shoes
# tutor
# simple
# life
# hour
# Enter_Tybalt
# comes
# word
# word
# Couple
# something
# make
# word
# shall_find_enough
# Could
# take
# thou_consortest
# thou_make_minstrels
# look
# hear_nothing
# talk
# public_haunt
# Either_withdraw_unto
# reason_coldly
# else_depart
# eyes_gaze
# Men’s_eyes_were_made
# peace
# he’ll_your_follower
# Your_worship
# better_term
# Thou
# That_thou_hast_done_therefore_turn
# Till_thou_shalt_know
# reason
# dearly
# What_wouldst_thou_have
# dry-beat
# rest
# Will_pluck_your_sword
# pilcher
# lest_mine
# Benvolio
# beat
# forbear
# Prince_expressly_hath_Forbid
# bandying
# fetch
# man
# hurt
# ’tis
# deep
# wide
# scratch
# Help
# They_have_made_worms’_meat
# beauty_hath_made_effeminate
# Which
# untimely
# scorn
# This
# begins
# Here_comes
# Again
# Away
# Staying
# thine
# Shalt
# citizens
# Stand
# Which
# There_lies
# attended
# their_Wives
# Where
# vile_beginners
# unlucky_manage
# There_lies
# slain
# blood
# ours_shed_blood
# began
# ’twixt_them_rushes
# underneath_whose_envious_thrust
# Tybalt
# fell_Romeo_turn
# This
# kinsman
# speaks
# twenty
# Romeo_must
# price
# Mercutio’s_friend
# fault_concludes
# life
# blood
# That_shall
# repent
# loss
# tears
# prayers_shall_purchase
# Romeo_hence
# Bear_hence
# Mercy
# pardoning
# bring
# Leap
# untalk’d
# best_agrees
# Play’d
# pair
# Whiter
# snow_upon
# will_make
# face
# heaven
# fine_That
# world_will
# love
# worship
# every_tongue
# cords
# Alack
# heaven
# ever
# This_torture
# roar’d
# thou
# Than
# death-darting
# eyes_shut
# Brief_sounds_determine
# weal
# save
# eyes
# ne’er_look
# Vile_earth
# earth_resign
# thou
# What_storm
# blows
# Romeo_slaughter’d
# Romeo
# did
# alas
# ever_dragon_keep
# fair
# Despised_substance
# Just_opposite
# When_thou_didst_bower
# spirit
# fiend_mortal_paradise
# ever_book_containing
# vile_matter
# There’s
# honesty
# Give
# Shame_come
# Blister’d_tongue
# born
# Upon_brow_shame_asham’d
# sit
# ’tis
# throne
# honour_crown’d_Sole_monarch
# Will_speak_well
# That_villain_cousin
# back
# Your_tributary_drops_belong
# Which_mistaking_offer
# Tybalt
# Like_damned_guilty_deeds
# words
# Where_father
# Weeping
# wailing
# Wash_they_wounds
# Take
# Hark_your_Romeo_will
# come
# come_forth
# thou_wedded
# What
# familiar_dear
# What_less
# doomsday
# exile_hath
# terror
# Much
# Hence
# world_broad
# There
# smilest_upon
# stroke
# hath_brush’d_aside
# turn’d
# black_word_death
# Live
# heaven
# look
# courtship_lives_carrion_flies
# steal_immortal_blessing
# even
# pure
# thinking_their
# say’st_thou
# exile
# sudden_mean
# though_ne’er
# banished
# Howlings_attends_Being
# mangle
# Hang
# talk
# wise_have
# dispute
# thee
# Thou_canst
# speak
# thou_dost
# Doting_like
# Taking
# measure
# Arise
# Mist-like_infold
# search
# Stand
# knocks
# There
# Even
# Blubbering
# weeping
# rise
# death’s
# Spakest_thou
# With_blood_remov’d
# little
# says_conceal’d_lady
# thou
# form_cries
# unreasonable_fury
# Unseemly_woman
# ill-beseeming_beast
# rail’st_thou
# heaven
# thee
# once
# thou
# usest_none
# true_indeed_Which
# afire
# thine
# thou_dismember’d
# thine
# whose_dear_sake_thou_wast
# Tybalt
# thou_slew’st_Tybalt
# turns
# exile
# like
# misshaped
# Thou_putt’st
# Fortune
# thee
# love
# hence
# pardon
# call_thee_back_With_twenty_hundred_thousand_times
# Than_thou_went’st_forth
# Commend
# hasten
# house
# sweet_prepare
# grows
# well_comfort_reviv’d
# Either_gone
# break
# disguis’d
# Every_good
# Give_hand
# ’tis_late
# farewell
# past_calls
# were
# grief
# brief
# part
# Lady_Capulet
# That_have
# time
# ’Tis
# late
# she’ll
# come
# These_times
# afford
# tune
# Commend
# Tonight_she’s_mew’d
# Wednesday
# shall_married
# like
# Juliet
# Light
# Afore
# late
# call_early
# Enter_Romeo
# That_pierc’d
# fearful_hollow
# thine_ear
# Nightly_sings
# herald
# lace
# severing_clouds
# jocund_Stands_tiptoe
# light_thee
# thou_need’st
# ’Tis
# pale_reflex
# vaulty_heaven
# high
# Straining_harsh_discords
# Some
# lark_makes_sweet_division
# This_doth
# divideth_Some
# lark
# Since
# Hunting_thee_hence
# hunt’s-up
# More_light
# dark
# Your_lady_mother_coming
# thou_gone
# minute
# sweet_discourses
# time
# dead
# bottom
# dost_thou
# That_renown’d
# Fortune
# is’t
# Evermore_weeping
# wilt_thou_wash
# grave
# thou_couldst
# much
# grief_shows_still
# want
# weep
# shall_feel
# thou_weep’st
# much
# death
# villain_lives
# That
# Villain
# That
# reach
# will_have_vengeance
# poor_heart
# That_Romeo
# come
# Upon_body
# comes_well
# Hath_sorted
# sudden
# Shall_happily_make_thee
# shall
# make
# husband_comes
# Rather
# will_take
# Enter_Capulet
# little_body_Thou_counterfeits
# Without
# Have_deliver’d
# sir
# Take
# take
# Doth
# Unworthy
# have_wrought_worthy
# gentleman
# thankful
# thankful_even
# hate
# fettle_your_fine_joints_’gainst_Thursday_next
# Paris
# Hear
# patience
# speak
# never
# look
# scarce_thought_blest_That_lent
# child
# have
# curse
# Good_prudence
# smatter
# Utter_your_gravity_o’er
# Proportion’d
# one’s_thought
# wish
# have
# Graze
# shall
# house
# Thursday_near
# hand
# That_sees
# bottom
# monument
# husband
# faith
# Unless
# husband_send
# Comfort_counsel_Upon
# soft
# subject
# Hast_thou
# word
# That_dares_ne’er_come_back
# needs_must
# Romeo’s
# dishclout
# Hath
# fair
# ’twere
# living
# Speakest_thou
# make_confession
# Which_hath_prais’d
# Thou
# myself_have_power
# Enter_Friar_Lawrence
# time
# know
# Immoderately_weeps
# Venus_smiles
# house
# much_minded
# know
# reason
# comes
# lady
# What_must_shall_That’s
# Come
# make_confession
# deny
# love_Being_spoke_behind_your_back
# face_much_abus’d
# tears_have_small_victory
# that
# enough
# Thou_wrong’st
# tears
# That
# thou_hast_slander’d
# must_entreat
# adieu
# keep
# Come_weep
# strains_past
# compass
# Thursday_next_married
# true_heart
# treacherous_revolt_Turn
# Which
# commission
# years
# Could
# issue
# thou_speak’st_speak
# Which_craves
# desperate
# execution
# desperate
# That_cop’st
# death_himself
# scape
# walk
# With_reeky_shanks
# live
# unstain’d_wife
# Nurse
# thee
# When_presently
# roses
# lips
# cheeks_shall_fade_paly_ashes
# Like_death
# shuts
# Each_part_depriv’d
# Shall_stiff
# stark
# Thou_shalt_continue
# awake
# rouse_thee
# Thou_shalt_borne
# ancient_vault_Where
# kindred
# Shall_Romeo
# night_Shall_Romeo_bear_thee_hence
# shall_free_thee
# inconstant
# womanish_fear_Abate_valour
# letters
# Nurse
# many_guests_invite
# ’tis
# cook
# lick
# fingers
# therefore
# lick_fingers_goes
# shall_much_unfurnish’d
# daughter_gone
# chance
# good
# comes
# shrift
# holy_Lawrence
# Send
# tell
# stepping_o’er
# bounds
# This_as’t
# whole_city_much_bound
# think
# We’ll
# shall_short
# thou
# help
# deck
# heart_wondrous_light_Since
# wayward_girl
# Enter_Juliet
# cross
# full
# madam
# have_cull’d
# necessaries_behoveful
# nurse
# night
# thee
# knows
# That_almost_freezes
# heat
# What
# What
# mixture
# work
# Because_married
# hath_still_been_tried
# Come
# redeem_There’s
# whose_foul_mouth
# healthsome_breathes
# Environed
# madly_play
# pluck
# mangled_Tybalt
# dash
# Seeking
# Romeo
# spit_body_Upon
# Enter_Lady_Capulet
# take
# keys
# fetch
# They_call
# dates
# quinces
# Look
# good_Angelica
# Spare
# bed
# you’ll_sick_tomorrow
# night
# logs
# will_show_thee
# never_trouble_Peter
# Mass
# well_said
# trim_Make_haste
# That_shall_rest
# forgive_Marry
# Will
# What
# she’s_dead
# alack
# Alack
# blood_settled
# Life
# Upon
# sweetest_flower
# hath_ta’en_hence
# Ties
# tongue
# will
# Enter_Friar_Lawrence
# Paris
# bride_ready
# Ready
# never
# Hath_death_lain
# Flower
# deflowered
# leave_all
# doth_give
# sight
# lasting_labour
# cruel_death_hath_catch’d
# Never_seen
# black
# Confusion’s_cure_lives
# better
# Your_part
# keep
# heaven_keeps_part
# Above
# high
# seeing
# she’s_best_married
# best_array_bear
# church
# though_fond_nature_bids
# bridal_flowers_serve
# things_change_them
# everyone_prepare_follow
# heavens_lower_upon
# ill
# Move_them
# pipes
# well_know
# merry_dump
# comfort
# dump_’tis
# time
# will
# What_will_give
# note_Pray
# Then_music
# ‘music
# silver_hath
# music
# silver_sound’
# musicians_have
# gold
# What
# pestilent_knave
# dreams_presage
# joyful_news
# Lifts
# ground
# gives
# dead_leave
# When
# love’s_shadows
# rich
# News
# Dost_thou
# bring_letters
# nothing
# immortal_part
# presently_took_post
# Since_leave
# Your_looks_pale
# Hast_thou
# letters
# enter
# thoughts
# Remnants
# cakes
# make
# need
# Whose_sale_present_death
# Here_lives
# caitiff_wretch
# calls
# violently
# hasty_powder_fir’d_Doth_hurry
# death
# fear’st
# Famine
# Need
# oppression_starveth
# Contempt
# world
# world’s_law
# world_affords
# make_thee_rich
# Then
# break
# Doing
# murder
# loathsome_world_Than
# poor_compounds
# thou_mayst
# thyself
# This
# voice
# Welcome
# speed
# Mantua
# bare_letter
# messenger
# fearful_were_they
# Within
# Hath
# notice
# accidents
# keep
# clos’d
# Page_bearing_flowers
# Hence
# digging
# thou_shalt_hear_Whistle
# signal
# tears_distill’d
# Nightly_shall
# strew_grave
# cross_obsequies
# Enter_Romeo
# Balthasar
# Give
# mattock
# take
# letter
# early
# morning_thou_deliver
# lord
# Whate’er_thou_hear’st
# stand
# aloof
# interrupt
# chiefly
# take_thence
# strew
# hungry_churchyard
# Than_empty_tigers
# vengeance_pursu’d
# tempt
# hence
# apprehend_thee
# Wilt_thou_provoke_Then_have
# Open
# betossed_soul_told_Paris
# writ
# beauty_makes_This_vault
# feasting_presence_full
# point
# Hath
# Thou
# death’s_pale_flag
# liest_thou
# sunder
# lean_abhorred_monster_keeps_Thee
# dark
# shake
# yoke
# inauspicious_stars_From
# Have_feet_stumbled
# What_torch_yond
# vainly_lends_light_burneth
# Full_half
# blood
# stains_stony_entrance
# discolour’d
# place
# steep’d
# unkind_hour_guilty
# husband
# bosom
# lies_dead
# Among
# sisterhood
# Stay
# Haply
# poison_doth_hang
# make
# Enter_Watch
# Page
# This
# Search
# hath_lain
# tell
# Prince
# Raise
# ground_whereon
# true_ground
# piteous_woes
# Re-enter
# Watch
# found
# Hold
# safety_till
# Re-enter_others
# Watch
# took
# mattock
# spade
# coming
# Enter
# Prince
# What_misadventure
# early_That_calls_person
# Lady_Capulet
# What
# they
# What_fear
# startles
# lies
# Warm
# know
# Here
# With_instruments_upon_them
# mis-sheathed
# That_warns
# Enter_Montague
# thou_early
# heir
# Grief
# What
# conspires
# press
# father
# Till_clear
# lead_even
# mischance_slave
# Bring_forth
# parties
# time
# place_Doth_make
# Myself_condemned
# Then
# thou_dost_know
# long
# husband
# whose_untimely_death_Banish’d
# new-made_bridegroom
# city
# remove
# siege
# grief
# devise
# means
# cell
# That
# hither_come
# dire_night_help
# take
# Being
# time
# potion’s_force
# stay’d
# accident
# noble_Paris
# bear
# work
# heaven
# violence
# Miscarried
# hour
# Unto
# rigour
# still_have_known_thee
# What
# post_came
# Mantua
# Where
# County’s_Page
# rais’d
# made_your_master
# This_letter_doth_make_good
# Their_course
# tidings
# writes
# poison
# therewithal_Came
# vault
# Where
# That_heaven_finds_means
# kill_your_joys
# Have_lost
# brace
# true
# Poor_sacrifices
# sorrow_will
# have
# talk
# Than
# Juliet

# %%
# Phrase frequency count
from operator import itemgetter
wordfreq = []
for u in range(len(phrases)):
    utterance = phrases[u]
    uttcnt = 0
    uttcnt = phrases.count(utterance)
    if uttcnt > 1:
        wordfreq.append(uttcnt)
    
zipped = list(zip(phrases, wordfreq))
sortzip = sorted(zipped, key=itemgetter(1), reverse=True)

for v in range(len(sortzip)):
    print(sortzip[v])
# Out:
# ('Page', 15)
# ('have_prest_With', 15)
# ('This_love', 15)
# ('keep', 15)
# ('rank_poison', 15)
# ('must_talk', 15)
# ('Thou_wilt_fall_backward', 15)
# ('rough', 15)
# ('kiss', 15)
# ('your_mother_craves', 15)
# ('have', 15)
# ('love', 15)
# ('already_sick', 15)
# ('What', 15)
# ('enemy', 15)
# ('Watchmen', 11)
# ('heads', 11)
# ('Thou_shalt', 11)
# ('sentence', 11)
# ('Your_lives_shall', 11)
# ('Alas', 11)
# ('tyrannous', 11)
# ('Alas', 11)
# ('strong_proof', 11)
# ('Then_hath_sworn', 11)
# ('Examine', 11)
# ('odds', 11)
# ('welcome', 11)
# ('splendour', 11)
# ('Enter_Lady_Capulet', 11)
# ('seek_happy_nights', 11)
# ('Torch-bearers', 11)
# ('shall', 11)
# ('mask', 11)
# ('Made', 11)
# ('prayer', 11)
# ('Saints', 11)
# ('feel_pretty_piece', 9)
# ('manage', 9)
# ('private', 9)
# ('Should', 9)
# ('rul’d', 9)
# ('margent', 9)
# ('Women_grow', 9)
# ('When_King_Cophetua_lov’d', 9)
# ('’tis', 9)
# ('fatal_loins', 7)
# ('stage', 7)
# ('sense', 7)
# ('fish', 7)
# ('stir_foot', 7)
# ('pain', 7)
# ('part', 7)
# ('portentous_must', 7)
# ('gentle', 7)
# ('pathways', 7)
# ('think', 7)
# ('teach', 7)
# ('seen', 7)
# ('Younger', 7)
# ('like', 7)
# ('mine', 7)
# ('Even', 7)
# ('nipple', 7)
# ('world—why_he’s', 7)
# ('Read_o’er', 7)
# ('gold_clasps_locks', 7)
# ('burden_love', 7)
# ('look', 7)
# ('save', 7)
# ('marchpane', 7)
# ('thou_loves', 7)
# ('Gentlewomen', 7)
# ('ill-beseeming_semblance', 7)
# ('saints_have_hands', 7)
# ('Shall_have', 7)
# ('trees_consorted', 7)
# ('bright_That_birds', 7)
# ('sing', 7)
# ('part_What’s', 7)
# ('were', 7)
# ('foes_Whose_misadventur’d_piteous_overthrows_Doth', 6)
# ('Enter_Sampson', 6)
# ('Gregory_armed', 6)
# ('being', 6)
# ('four_Citizens', 6)
# ('Could', 6)
# ('merit_bliss', 6)
# ('hath_forsworn', 6)
# ('stand', 6)
# ('Whither', 6)
# ('Where’s', 6)
# ('Susan', 6)
# ('When_taste', 6)
# ('marry', 6)
# ('find_delight_writ', 6)
# ('fair_within', 6)
# ('waste_lights', 6)
# ('Well', 6)
# ('swears', 6)
# ('With', 6)
# ('’tis', 6)
# ('please', 6)
# ('quench', 6)
# ('This', 6)
# ('fleer', 6)
# ('foe', 6)
# ('solemnity', 6)
# ('You’ll_make', 6)
# ('wilful_choler_meeting_Makes_flesh_tremble', 6)
# ('Have', 6)
# ('Then_have_lips', 6)
# ('known', 6)
# ('fair', 6)
# ('Having', 6)
# ('sails_upon', 6)
# ('Retain', 6)
# ('hours’_traffic', 5)
# ('bite_your_thumb', 5)
# ('Enter_Capulet', 5)
# ('pain', 5)
# ('bloody_hands_Throw_your_mistemper’d_weapons', 5)
# ('forfeit', 5)
# ('makes_himself', 5)
# ('Have_importun’d', 5)
# ('cousin_Tybalt', 5)
# ('Come_Lammas', 5)
# ('have', 5)
# ('theme_stands_your_disposition', 5)
# ('Here', 5)
# ('ladies', 5)
# ('count_That', 5)
# ('everything', 5)
# ('Maskers', 5)
# ('Here', 5)
# ('’tis', 5)
# ('frozen_bosom', 5)
# ('Susan_Grindstone', 5)
# ('Antony', 5)
# ('room_grown', 5)
# ('Were', 5)
# ('doth_enrich', 5)
# ('scorn', 5)
# ('Enter_Benvolio', 5)
# ('cold', 5)
# ('vestal_livery', 5)
# ('Deny_father', 5)
# ('swords', 4)
# ('weakest_goes', 4)
# ('Enter_Abram', 4)
# ('sides', 4)
# ('them', 4)
# ('Enter_three', 4)
# ('seek', 4)
# ('grove', 4)
# ('gladly_shunn’d', 4)
# ('Black', 4)
# ('learn', 4)
# ('rough', 4)
# ('Tell', 4)
# ('That', 4)
# ('forget_precious_treasure', 4)
# ('thou_canst', 4)
# ('pity_’tis_liv’d', 4)
# ('their_pride_think_ripe', 4)
# ('view', 4)
# ('Whipp’d', 4)
# ('Lucio', 4)
# ('Thou_knowest_daughter’s', 4)
# ('She’s', 4)
# ('days', 4)
# ('—God_rest', 4)
# ('Were', 4)
# ('wormwood', 4)
# ('Thou_wilt_fall_backward', 4)
# ('Verona’s_summer_hath', 4)
# ('love', 4)
# ('love_rough', 4)
# ('beetle-brows_shall_blush', 4)
# ('starts', 4)
# ('blows', 4)
# ('term', 4)
# ('breast', 4)
# ('porter', 4)
# ('asked', 4)
# ('Such', 4)
# ('Some_five', 4)
# ('shows', 4)
# ('snowy_dove_trooping', 4)
# ('Here', 4)
# ('You’ll', 4)
# ('lips', 4)
# ('mother', 4)
# ('let’s', 4)
# ('heir', 4)
# ('grave_like', 4)
# ('Prodigious_birth', 4)
# ('likeness_thou_appear', 4)
# ('love', 4)
# ('kind', 4)
# ('thou', 4)
# ('vain_seek', 4)
# ('What', 4)
# ('team', 3)
# ('toil_shall_strive', 3)
# ('That_shows_thee', 3)
# ('ever_thrust', 3)
# ('They_must_take', 3)
# ('house', 3)
# ('Turn_back', 3)
# ('take', 3)
# ('better', 3)
# ('part', 3)
# ('bills', 3)
# ('were', 3)
# ('fought', 3)
# ('sycamore_That_westward_rooteth', 3)
# ('gladly_fled', 3)
# ('Shuts', 3)
# ('locks_fair_daylight', 3)
# ('love', 3)
# ('Feather', 3)
# ('Dost_thou', 3)
# ('Which_thou_wilt_propagate', 3)
# ('thou_hast_shown_Doth', 3)
# ('he’s', 3)
# ('sadness', 3)
# ('wisely', 3)
# ('strucken_blind', 3)
# ('Paris', 3)
# ('hath', 3)
# ('soon_marr’d', 3)
# ('house', 3)
# ('With', 3)
# ('burnt', 3)
# ('weigh’d_Your_lady’s_love', 3)
# ('rejoice', 3)
# ('fall', 3)
# ('waddled', 3)
# ('—God', 3)
# ('thou_hast', 3)
# ('wit', 3)
# ('age', 3)
# ('valiant_Paris_seeks', 3)
# ('he’s', 3)
# ('This_night_shall_behold', 3)
# ('Find_written', 3)
# ('sea', 3)
# ('shall_share', 3)
# ('making_yourself', 3)
# ('Enter', 3)
# ('shall', 3)
# ('speech_spoke', 3)
# ('soar', 3)
# ('great_oppression', 3)
# ('boisterous', 3)
# ('every_betake', 3)
# ('that’s', 3)
# ('going', 3)
# ('joiner_squirrel', 3)
# ('Time', 3)
# ('mind', 3)
# ('Turning_side', 3)
# ('This_wind_talk', 3)
# ('vile_forfeit', 3)
# ('Guests', 3)
# ('corns_will_have', 3)
# ('sir', 3)
# ('Beauty', 3)
# ('rich', 3)
# ('scorn', 3)
# ('you’ll', 3)
# ('though_grant', 3)
# ('What’s', 3)
# ('What’s', 3)
# ('strangers', 3)
# ('love_groan’d', 3)
# ('That', 3)
# ('wish_mistress_were', 3)
# ('open-arse', 3)
# ('shall_then', 3)
# ('pale', 3)
# ('Would', 3)
# ('name', 3)
# ('dear_perfection', 3)
# ('owes_Without', 3)
# ('part', 3)
# ('From_ancient_grudge_break', 2)
# ('From_forth', 2)
# ('What', 2)
# ('we’ll', 2)
# ('draw_your_neck', 2)
# ('thou', 2)
# ('quickly_moved', 2)
# ('move', 2)
# ('stir', 2)
# ('valiant', 2)
# ('thrust_maids', 2)
# ('quarrel', 2)
# ('masters', 2)
# ('heads', 2)
# ('their_maidenheads', 2)
# ('take', 2)
# ('well_thou', 2)
# ('Draw_tool', 2)
# ('comes', 2)
# ('they_bear_bite_your_thumb', 2)
# ('comes', 2)
# ('know', 2)
# ('thou_drawn_among', 2)
# ('Have', 2)
# ('Down', 2)
# ('Down', 2)
# ('flourishes_blade', 2)
# ('spite', 2)
# ('Enter_Montague', 2)
# ('Will_they', 2)
# ('ground_hear', 2)
# ('Canker’d', 2)
# ('know_farther_pleasure', 2)
# ('swung', 2)
# ('hiss’d', 2)
# ('Came', 2)
# ('Till', 2)
# ('Where_underneath', 2)
# ('stole', 2)
# ('covert', 2)
# ('Unless_good_counsel', 2)
# ('know', 2)
# ('envious_worm_spread_sweet_leaves', 2)
# ('dedicate_beauty', 2)
# ('willingly_give_cure', 2)
# ('father', 2)
# ('went_hence', 2)
# ('having', 2)
# ('Misshapen_chaos', 2)
# ('grief', 2)
# ('much', 2)
# ('This', 2)
# ('hath_Dian’s_wit', 2)
# ('Cuts_beauty', 2)
# ('wise', 2)
# ('forget', 2)
# ('What_doth_beauty_serve', 2)
# ('change', 2)
# ('fourteen_years', 2)
# ('summers_wither', 2)
# ('Lies_consent', 2)
# ('even', 2)
# ('delight_Among_fresh_female_buds_shall', 2)
# ('night_Inherit', 2)
# ('whose_merit', 2)
# ('though', 2)
# ('Find_them', 2)
# ('Enter_Benvolio', 2)
# ('Your_plantain_leaf_excellent', 2)
# ('bound', 2)
# ('madman_Shut', 2)
# ('fortune', 2)
# ('Signior_Valentio', 2)
# ('admired_beauties', 2)
# ('fairer', 2)
# ('all-seeing_Ne’er_match_since_first', 2)
# ('crystal_scales', 2)
# ('maid_shall_scant_show_well', 2)
# ('Call_forth', 2)
# ('This', 2)
# ('about', 2)
# ('even', 2)
# ('thou_comest', 2)
# ('faith', 2)
# ('feast', 2)
# ('volume', 2)
# ('fish_lives', 2)
# ('’tis_much_pride_fair_without', 2)
# ('That', 2)
# ('golden_story', 2)
# ('like', 2)
# ('Than_your_consent_gives_strength', 2)
# ('Nurse_cursed', 2)
# ('five', 2)
# ('them_measure', 2)
# ('We’ll_measure_them', 2)
# ('them', 2)
# ('sink', 2)
# ('love', 2)
# ('love', 2)
# ('Prick_love', 2)
# ('wherein_thou_stickest', 2)
# ('light_lights', 2)
# ('judgment_sits_Five_times', 2)
# ('mean_well', 2)
# ('Drums', 2)
# ('wakes', 2)
# ('Thou_talk’st', 2)
# ('Even', 2)
# ('puffs_away', 2)
# ('shall_come', 2)
# ('night’s_revels', 2)
# ('expire', 2)
# ('clos’d', 2)
# ('hath', 2)
# ('steerage', 2)
# ('helps', 2)
# ('shift', 2)
# ('scrape', 2)
# ('When_good_manners_shall', 2)
# ('Away', 2)
# ('remove', 2)
# ('piece', 2)
# ('looked', 2)
# ('ladies', 2)
# ('have_their_toes_Unplagu’d', 2)
# ('bout', 2)
# ('Will_deny', 2)
# ('Come_Pentecost', 2)
# ('quickly', 2)
# ('twenty_years', 2)
# ('earth', 2)
# ('virtuous', 2)
# ('will', 2)
# ('Show', 2)
# ('fair_presence', 2)
# ('’tis', 2)
# ('princox', 2)
# ('Patience_perforce', 2)
# ('convert', 2)
# ('ready_stand_smooth', 2)
# ('rough_touch', 2)
# ('palm', 2)
# ('they_must', 2)
# ('lest_faith_turn', 2)
# ('Thus', 2)
# ('word', 2)
# ('lady', 2)
# ('wise', 2)
# ('gone', 2)
# ('sport', 2)
# ('prepare', 2)
# ('Come', 2)
# ('going', 2)
# ('love_sprung', 2)
# ('That_fair', 2)
# ('Tempering_extremities', 2)
# ('life_hath_stol’n_home', 2)
# ('leap’d', 2)
# ('Appear_thou', 2)
# ('likeness', 2)
# ('demesnes', 2)
# ('This', 2)
# ('Till_laid', 2)
# ('conjur’d_down', 2)
# ('That_were', 2)
# ('hath_himself_among', 2)
# ('best_befits', 2)
# ('will', 2)
# ('fruit_maids_call_medlars', 2)
# ('This_field-bed', 2)
# ('means', 2)
# ('jests', 2)
# ('scars', 2)
# ('never_felt', 2)
# ('Juliet_appears', 2)
# ('light', 2)
# ('Juliet', 2)
# ('That_thou_maid', 2)
# ('sick', 2)
# ('none', 2)
# ('fairest_stars', 2)
# ('entreat_eyes_twinkle', 2)
# ('they', 2)
# ('airy_region_stream', 2)
# ('think_were', 2)
# ('bosom', 2)
# ('though', 2)

# %% [markdown]
# # TF-IDF
#
# https://cdn-images-1.medium.com/max/800/1*nSqHXwOIJ2fa_EFLTh5KYw.png

# %%
# Computes ratio of word's appearances to total words
def computeTF(wordDict, bow): 
    bowCount = len(bow) #BOW = Bag of Words
    tfDict = {}
    for word, count in wordDict.items():
        tfDict[word] = count/float(bowCount)
    return tfDict

# %%
# Calculates the weight of rare words across all docs
def computeIDF(docList):
    import math
    idfDict = {}
    N = len(docList)
    
    idfDict = dict.fromkeys(docList[0].keys(), 0)
    for doc in docList:
        for word, val in doc.items():
            if val > 0:
                idfDict[word] += 1
                
    for word, val in idfDict.items():
        idfDict[word] = math.log10(N / float(val))
    
    return idfDict

# %%
def computeTFIDF(tfBow, idfs):
    tfidf = {}
    for word, val in tfBow.items():
        tfidf[word] = val*idfs[word]
    return tfidf
